# %% [markdown]
# # Smoke test -- run this on Kaggle, Colab and local before Day 1
# Every teammate: clone, run all cells, screenshot the last output into the team chat.

# %%
import os, subprocess, sys
REPO = 'https://github.com/<ORG>/amazon-ml-2026.git'   # <-- set your repo URL
if not os.path.exists('amazon-ml-2026'):
    subprocess.run(['git','clone',REPO], check=True)
# %cd amazon-ml-2026

# %%
# !pip install -q -r requirements.txt

# %%
# !python scripts/check_env.py

# %%
# !python tests/smoke_test.py

# %%
# !python run_baseline.py --demo

# %% [markdown]
# ## GPU box only: transformer dry run (checks download, tokenizer, OOM at your batch size / max_length, mixed precision)

# %%
# !python -m src.transformer --model microsoft/deberta-v3-base --max_length 256 --batch_size 16
